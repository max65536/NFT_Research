# %%
import pandas as pd
from pytrends.request import TrendReq

# %%
pytrend = TrendReq(hl='en-US',tz=360)

# %%
def datetime_to_day(s):
    return s.split()[0]

# %%
def merge_dump(name):
    df = pd.read_csv('data/SVI/SVI_%s.csv'%name, converters={'date':datetime_to_day}).drop(['isPartial'], axis=1)
    new_df = df.groupby('date').sum()
    new_df[:365].to_csv('data/SVI/merged_SVI_%s.csv'%name)
    print(new_df.head())

# %%
data_NFT = pytrends.get_historical_interest(['NFT'], year_start=2021, month_start=10, day_start=5,hour_start=0,
                                 year_end=2022, month_end=10, day_end=5, hour_end=0, 
                                 geo='', gprop='', sleep=60
                                )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9b1991a450c6> in <module>
# ----> 1 data_NFT = pytrends.get_historical_interest(['NFT'], year_start=2021, month_start=10, day_start=5,hour_start=0,
#       2                                  year_end=2022, month_end=10, day_end=5, hour_end=0,
#       3                                  geo='', gprop='', sleep=60
#       4                                 )
#
# NameError: name 'pytrends' is not defined

# %%
keywords = pytrend.suggestions(keyword='Facebook')
df = pd.DataFrame(keywords)
df.head(5)
# Out:
#              mid            title        type
# 0     /m/0k2ljgx        Messenger       Topic
# 1  /g/11hmdd2rxz    Facebook Lite    Software
# 2    /m/0102936k        Oculus VR     Company
# 3  /g/11f2w5n9rf   Facebook Watch  TV network
# 4  /g/11f7r5zhgh  Facebook Dating    Web site

# %%
df = pytrend.top_charts(2020, hl='en-US', tz=300, geo='GLOBAL')
df.head()
# Out:
#               title exploreQuery
# 0       Coronavirus
# 1  Election results
# 2       Kobe Bryant
# 3              Zoom
# 4               IPL

# %%
kw_list=['Facebook', 'Apple', 'Amazon', 'Netflix', 'Google']

#search interest per region
#run model for keywords (can also be competitors)
pytrend.build_payload(kw_list, timeframe='today 1-m')

# Interest by Region
regiondf = pytrend.interest_by_region()
#looking at rows where all values are not equal to 0
regiondf = regiondf[(regiondf != 0).all(1)] 

#drop all rows that have null values in all columns
regiondf.dropna(how='all',axis=0, inplace=True)

#visualise
regiondf.plot(figsize=(20, 12), y=kw_list, kind ='bar')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-6-891f27766774> in <module>
#       6
#       7 # Interest by Region
# ----> 8 regiondf = pytrend.interest_by_region()
#       9 #looking at rows where all values are not equal to 0
#      10 regiondf = regiondf[(regiondf != 0).all(1)]
#
# C:\MyPrograms\Anaconda3\lib\site-packages\pytrends\request.py in interest_by_region(self, resolution, inc_low_vol, inc_geo_code)
#     293             method=TrendReq.GET_METHOD,
#     294             trim_chars=5,
# --> 295             params=region_payload,
#     296         )
#     297         df = pd.DataFrame(req_json['default']['geoMapData'])
#
# C:\MyPrograms\Anaconda3\lib\site-packages\pytrends\request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     158                 'The request failed: Google returned a '
# ...

# %%
kw_list =

# %%
df_NFT = pytrend.get_historical_interest(['NFT'], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df_BAYC = pytrend.get_historical_interest(['BAYC'], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
# Out:
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df_cryptopunks = pytrend.get_historical_interest(['cryptopunks'], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
# Out:
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df_bored_ape = pytrend.get_historical_interest(['bored ape yacht club'], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df_metaverse = pytrend.get_historical_interest(['metaverse'], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df_NFT.to_csv('data/SVI_NFT_all.csv')

# %%
df_BAYC.to_csv('data/SVI_BAYC_all.csv')

# %%
df_cryptopunks.to_csv('data/SVI_cryptopunks_all.csv')

# %%
df_bored_ape.to_csv('data/SVI_bored_ape_all.csv')

# %%
df_metaverse.to_csv('data/SVI_metaverse_all.csv')

# %%
df_NFT
# Out:
#                      NFT  isPartial
# date
# 2017-06-23 00:00:00    0      False
# 2017-06-23 01:00:00    0      False
# 2017-06-23 02:00:00    0      False
# 2017-06-23 03:00:00    0      False
# 2017-06-23 04:00:00    0      False
# ...                  ...        ...
# 2022-11-04 20:00:00   77      False
# 2022-11-04 21:00:00   75      False
# 2022-11-04 22:00:00   77      False
# 2022-11-04 23:00:00   75      False
# 2022-11-05 00:00:00   75      False
#
# [30952 rows x 2 columns]

# %%
name_list = [
 'ENS',
 'Rarible',
 'Zora',
 'OpenSea Shared Storefront',
 'Otherdeed',
 'MutantApeYachtClub',
 'Art Blocks',
 'KnownOriginDigitalAsset',
 'Uniswap V3 Positions']

# %%
for name in name_list:
    df = pytrend.get_historical_interest([name], year_start=2017, month_start=6, day_start=23, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                               cat=0, geo='', gprop='', sleep=0)
    df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22ENS%22%2C+%22time%22%3A+%222017-06-23T00+2017-06-30T00%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AF3EF8B508>, 'Connection to trends.google.com timed out. (connect timeout=2)'))
# HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22ENS%22%2C+%22time%22%3A+%222017-06-30T00+2017-07-07T00%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+0%2C+%22property%22%3A+%22%22%7D (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x000002AF3EEF9208>, 'Connection to trends.google.com timed out. (connect timeout=2)'))
# ...

# %%
name = 'ENS'
df = pytrend.get_historical_interest([name], year_start=2020, month_start=2, day_start=6, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
df
# Out:
#                      Rarible  isPartial
# date
# 2020-07-30 00:00:00        0      False
# 2020-07-30 01:00:00        0      False
# 2020-07-30 02:00:00        0      False
# 2020-07-30 03:00:00        0      False
# 2020-07-30 04:00:00        0      False
# ...                      ...        ...
# 2022-11-04 20:00:00       43      False
# 2022-11-04 21:00:00       64      False
# 2022-11-04 22:00:00       53      False
# 2022-11-04 23:00:00       51      False
# 2022-11-05 00:00:00       56      False
#
# [6978 rows x 2 columns]

# %%
name = 'Rarible'
df = pytrend.get_historical_interest([name], year_start=2020, month_start=5, day_start=28, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# ...

# %%
['Zora',
 'OpenSea Shared Storefront',
 'Otherdeed',
 'Mutant Ape Yacht Club',
 'Art Blocks',
 'KnownOrigin',
 'Uniswap']

# %%
name = 'Zora'
df = pytrend.get_historical_interest([name], year_start=2021, month_start=1, day_start=30, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# ...

# %%
name = 'OpenSea Shared Storefront'
df = pytrend.get_historical_interest([name], year_start=2020, month_start=12, day_start=6, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# ...

# %%
name = 'Otherdeed'
df = pytrend.get_historical_interest([name], year_start=2022, month_start=5, day_start=1, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
name = 'Mutant Ape Yacht Club'
df = pytrend.get_historical_interest([name], year_start=2021, month_start=8, day_start=29, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
name = 'Art Blocks'
df = pytrend.get_historical_interest([name], year_start=2020, month_start=12, day_start=12, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
name = 'KnownOrigin'
df = pytrend.get_historical_interest([name], year_start=2018, month_start=11, day_start=10, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=2)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# ...

# %%
name = 'Uniswap'
df = pytrend.get_historical_interest([name], year_start=2021, month_start=5, day_start=5, hour_start=0, year_end=2022, month_end=11, day_end=5, hour_end=0, 
                                           cat=0, geo='', gprop='', sleep=0)
df.to_csv('data/SVI_%s_all.csv'%name)
