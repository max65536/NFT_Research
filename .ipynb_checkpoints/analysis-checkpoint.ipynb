# %%
import requests
import pandas as pd
import collect_data 
import pickle

# %% [markdown]
# # Questions

# %% [markdown]
# 1. Which price is better?  Open price, close price, high price or low price?
# 2. Which variable is better? Price or Volume?
# 3. When should I use log in linear model?

# %% [markdown]
# # Data overview

# %% [markdown]
# ### NFT market

# %% [markdown]
# [x] primary sale (PrimarySale),
# [x] secondary sale,
# [x] primary sale USD,
# [x] secondary sale USD,
# [x] and control for the changes in the number of unique wallets (ΔNumWallets),
# [x] the number of buyers (ΔNumBuyers),
# [x] the number of sellers (ΔNumSellers),
# [x] the number of sales (ΔNumSales),
# [x] the sales volume in USD (ΔSalesUSD),

# %% [markdown]
# ### External enviroment

# %% [markdown]
# [ ] ETHUSD exchange rate (ΔETHUSD),
# [ ] the ETH trading volume (ΔETHVol)
# [ ] Google Index: worldwide attention to Ethereum (Adj. SVI)

# %% [markdown]
# # Load data

# %%
df_NFT = pd.read_csv('data/Data_NFT.csv')
df_NFT["DateTime"] = pd.to_datetime(df_NFT["DateTime"])

# %%
def color_corr_level(val):
    val = abs(val)
    if val>0.8:
        color = 'red'
    elif val>0.3:
        color = 'orange'
    else:
        color = 'black'
    return 'color:%s'%color

# %%
df_NFT.corr().style.applymap(color_corr_level)
# Out:
# <style  type="text/css" >
#     #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col0 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col1 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col2 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col4 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col5 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col8 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow0_col9 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col0 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col1 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col2 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col4 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col5 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col8 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow1_col9 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col0 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col1 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col2 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col4 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col5 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col8 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow2_col9 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col0 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col1 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col2 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col3 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col4 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col5 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col6 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col7 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col8 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow3_col9 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col0 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col1 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col2 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col4 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col5 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col8 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow4_col9 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col0 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col1 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col2 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col4 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col5 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col8 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow5_col9 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col0 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col1 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col2 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col3 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col4 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col5 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col6 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col8 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow6_col9 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col0 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col1 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col2 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col3 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col4 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col5 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col7 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col8 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow7_col9 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col0 {
#             color: black;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col1 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col2 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col3 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col4 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col5 {
#             color: red;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col6 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col7 {
#             color: orange;
#         }    #T_9a6775ae_4647_11ed_aca5_c0b5d78bc74erow8_col8 {
#             color: re

# %% [markdown]
# ### External indice

# %%
df_BTC = pd.read_csv('data/BTC-USD.csv')
df_BTC=df_BTC.rename(columns={"Open":"Open_BTC"})
df_ETH = pd.read_csv('data/ETH-USD.csv')
df_ETH=df_ETH.rename(columns={"Open":"Open_ETH"})
df_NASDAQ = pd.read_csv('data/NASDAQ.csv')
df_NASDAQ=df_NASDAQ.rename(columns={"Open":"Open_NASDAQ"})
df_USD = pd.read_csv('data/USD_index.csv')
df_USD=df_USD.rename(columns={"Open":"Open_USD"})
# df_ETH.rename(columns={"Open":"open_ETH", "High":"high_ETH", "Low":"low_ETH", "Close":"close_ETH", "Adj Close":"adj_close_ETH", "Volume":"volume_ETH"})

# %%
df_USD.head()
# Out:
#          Date   Open_USD       High        Low      Close  Adj Close  Volume
# 0  2021-10-05  93.830002  94.070000  93.809998  93.980003  93.980003     0.0
# 1  2021-10-06  93.989998  94.449997  93.980003  94.269997  94.269997     0.0
# 2  2021-10-07  94.230003  94.279999  94.080002  94.220001  94.220001     0.0
# 3  2021-10-08  94.209999  94.339996  93.940002  94.070000  94.070000     0.0
# 4  2021-10-10        NaN        NaN        NaN        NaN        NaN     NaN

# %%
# pd.concat([df_extern, df_USD[['Date','Open_USD']]], sort=False, axis=1)
df_extern = df_ETH[['Date','Open_ETH']].merge(
    df_BTC[['Date','Open_BTC']]).merge(
    df_USD[['Date', 'Open_USD']]).merge(
    df_NASDAQ[['Date','Open_NASDAQ']])

# %%
df_extern.corr()
# Out:
#              Open_ETH  Open_BTC  Open_USD  Open_NASDAQ
# Open_ETH     1.000000  0.969808 -0.863497     0.950447
# Open_BTC     0.969808  1.000000 -0.901132     0.911923
# Open_USD    -0.863497 -0.901132  1.000000    -0.865431
# Open_NASDAQ  0.950447  0.911923 -0.865431     1.000000

# %%
df_extern = pd.concat([df_ETH[['Date',]], df_BYAC.drop('timestamp', axis=1).astype('float64')], axis=1, join='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dae50b51582b> in <module>
# ----> 1 df_extern = pd.concat([df_ETH[['Date',]], df_BYAC.drop('timestamp', axis=1).astype('float64')], axis=1, join='inner')
#
# NameError: name 'df_BYAC' is not defined

# %% [markdown]
# # BYAC and Cryptopunk

# %%
ranks = collect_data.top100_value()

# %%
print(ranks[3].name)
print(ranks[3].address)
BYAC_address = ranks[3].address
# Out:
# BoredApeYachtClub
# 0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d

# %%
BYAC_data = collect_data.collection_price(contract_address=BYAC_address, endtime="2022-10-05T00:00:00Z")

# %%
BYAC_data_05 = collect_data.collection_price(contract_address=BYAC_address, endtime="2022-10-06T00:00:00Z")

# %%
BYAC_data['dataPoints'][-1]
# Out:
# {'timestamp': '2022-10-04T00:00:00Z',
#  'min': '61.8200392304197776',
#  'max': '150',
#  'avg': '93.6440078460839555'}

# %%
BYAC_data_05['dataPoints'][-1]
# Out:
# {'timestamp': '2022-10-05T00:00:00Z',
#  'min': '72.9775957080854495',
#  'max': '100.1423550633253784',
#  'avg': '84.3566502571369426'}

# %%
df_BYAC = pd.DataFrame(BYAC_data['dataPoints']+[BYAC_data['dataPoints'][-1]])

# %%
df_BYAC
# Out:
#                 timestamp                  min  max                   avg
# 0    2021-10-05T00:00:00Z               35.269   65   46.1510344827586207
# 1    2021-10-06T00:00:00Z                 10.5   90            41.5033411
# 2    2021-10-07T00:00:00Z            21.643836   99   44.6864021176470588
# 3    2021-10-08T00:00:00Z               31.505   53           39.02653125
# 4    2021-10-09T00:00:00Z               31.005  110   48.5333470588235294
# ..                    ...                  ...  ...                   ...
# 361  2022-10-01T00:00:00Z  50.4028497096936034  777  245.2569624274234009
# 362  2022-10-02T00:00:00Z                72.99  144    90.392353611981722
# 363  2022-10-03T00:00:00Z  22.7237874628446507  112   69.2275240368939183
# 364  2022-10-04T00:00:00Z  61.8200392304197776  150   93.6440078460839555
# 365  2022-10-04T00:00:00Z  61.8200392304197776  150   93.6440078460839555
#
# [366 rows x 4 columns]

# %%
df_BYAC.rename(columns={"min": "min_price_BYAC", "max": "max_price_BYAC", "avg":"avg_price_BYAC"})
# Out:
#                 timestamp       min_price_BYAC max_price_BYAC  \
# 0    2021-10-05T00:00:00Z               35.269             65
# 1    2021-10-06T00:00:00Z                 10.5             90
# 2    2021-10-07T00:00:00Z            21.643836             99
# 3    2021-10-08T00:00:00Z               31.505             53
# 4    2021-10-09T00:00:00Z               31.005            110
# ..                    ...                  ...            ...
# 361  2022-10-01T00:00:00Z  50.4028497096936034            777
# 362  2022-10-02T00:00:00Z                72.99            144
# 363  2022-10-03T00:00:00Z  22.7237874628446507            112
# 364  2022-10-04T00:00:00Z  61.8200392304197776            150
# 365  2022-10-04T00:00:00Z  61.8200392304197776            150
#
#            avg_price_BYAC
# 0     46.1510344827586207
# 1              41.5033411
# 2     44.6864021176470588
# 3             39.02653125
# 4     48.5333470588235294
# ..                    ...
# 361  245.2569624274234009
# 362    90.392353611981722
# 363   69.2275240368939183
# 364   93.6440078460839555
# 365   93.6440078460839555
#
# [366 rows x 4 columns]

# %%
df_BYAC.drop('timestamp', axis=1).astype('float64')
# Out:
#            min    max         avg
# 0    35.269000   65.0   46.151034
# 1    10.500000   90.0   41.503341
# 2    21.643836   99.0   44.686402
# 3    31.505000   53.0   39.026531
# 4    31.005000  110.0   48.533347
# ..         ...    ...         ...
# 361  50.402850  777.0  245.256962
# 362  72.990000  144.0   90.392354
# 363  22.723787  112.0   69.227524
# 364  61.820039  150.0   93.644008
# 365  61.820039  150.0   93.644008
#
# [366 rows x 3 columns]

# %%
df_all = pd.concat([df_ETH.drop(labels="Date",axis=1), df_BYAC.drop('timestamp', axis=1).astype('float64')], axis=1, join='inner')

# %%
df_all.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.998307  0.996452  0.994385   0.994385  0.091593
# High       0.998307  1.000000  0.996610  0.996945   0.996945  0.104323
# Low        0.996452  0.996610  1.000000  0.997561   0.997561  0.048475
# Close      0.994385  0.996945  0.997561  1.000000   1.000000  0.071375
# Adj Close  0.994385  0.996945  0.997561  1.000000   1.000000  0.071375
# Volume     0.091593  0.104323  0.048475  0.071375   0.071375  1.000000
# min       -0.381571 -0.390260 -0.381714 -0.390844  -0.390844 -0.095454
# max       -0.181816 -0.179390 -0.178204 -0.177929  -0.177929 -0.004437
# avg       -0.469171 -0.473976 -0.462961 -0.471658  -0.471658 -0.187451
#
#                 min       max       avg
# Open      -0.381571 -0.181816 -0.469171
# High      -0.390260 -0.179390 -0.473976
# Low       -0.381714 -0.178204 -0.462961
# Close     -0.390844 -0.177929 -0.471658
# Adj Close -0.390844 -0.177929 -0.471658
# Volume    -0.095454 -0.004437 -0.187451
# min        1.000000  0.031778  0.474809
# max        0.031778  1.000000  0.517728
# avg        0.474809  0.517728  1.000000
