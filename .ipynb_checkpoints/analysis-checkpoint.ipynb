# %%
import requests
import pandas as pd
import collect_data

# %%
df = pd.read_csv('data/number_sales_and_sales_USD.csv')

# %%
df

# %%
df_ETH = pd.read_csv('data/ETH-USD.csv')

# %%
df_ETH.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998307  0.996452  0.994385   0.994385  0.091593
# High       0.998307  1.000000  0.996610  0.996945   0.996945  0.104323
# Low        0.996452  0.996610  1.000000  0.997561   0.997561  0.048475
# Close      0.994385  0.996945  0.997561  1.000000   1.000000  0.071375
# Adj Close  0.994385  0.996945  0.997561  1.000000   1.000000  0.071375
# Volume     0.091593  0.104323  0.048475  0.071375   0.071375  1.000000

# %%
ranks = collect_data.top100_value()

# %%
print(ranks[3].name)
print(ranks[3].address)
BYAC_address = ranks[3].address
# Out:
# BoredApeYachtClub
# 0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d

# %%
BYAC_data = collect_data.collection_price(contract_address=BYAC_address, endtime="2022-10-05T00:00:00Z")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-2bd4074c0454> in <module>
# ----> 1 BYAC_data = collect_data.collection_price(contract_address=BYAC_address, endtime="2022-10-05T00:00:00Z")
#
# TypeError: collection_price() got an unexpected keyword argument 'endtime'

# %%
BYAC_data
# Out:
# {'dataPoints': [{'timestamp': '2021-10-01T00:00:00Z',
#    'min': '37.005',
#    'max': '76.66',
#    'avg': '48.4557692307692308'},
#   {'timestamp': '2021-10-02T00:00:00Z',
#    'min': '20.986301',
#    'max': '63',
#    'avg': '44.3129000357142857'},
#   {'timestamp': '2021-10-03T00:00:00Z',
#    'min': '39',
#    'max': '65.005',
#    'avg': '45.7282608695652174'},
#   {'timestamp': '2021-10-04T00:00:00Z',
#    'min': '21.479452',
#    'max': '300.005',
#    'avg': '55.4129264605255972'},
#   {'timestamp': '2021-10-05T00:00:00Z',
#    'min': '35.269',
#    'max': '65',
#    'avg': '46.1510344827586207'},
#   {'timestamp': '2021-10-06T00:00:00Z',
#    'min': '10.5',
#    'max': '90',
#    'avg': '41.5033411'},
#   {'timestamp': '2021-10-07T00:00:00Z',
#    'min': '21.643836',
#    'max': '99',
#    'avg': '44.6864021176470588'},
#   {'timestamp': '2021-10-08T00:00:00Z',
#    'min': '31.505',
#    'max': '53',
#    'avg': '39.02653125'},
#   {'timestamp': '2021-10-09T00:00:00Z',
# ...
